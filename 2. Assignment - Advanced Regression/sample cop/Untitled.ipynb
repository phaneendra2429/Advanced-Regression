# %%
model = Ridge()

# %%
# rfe = RFE(model, 20 )

# %%
# rfe = rfe.fit(X_train, y_train)

# %%
# X_train = X_train[X_train.columns[rfe.support_]]

# %%
len(X_train.columns)
# Out:
# 280

# %%
model.fit(X_train,y_train)
# Out:
# Ridge()

# %%
zp = list(zip(X_train.columns,model.coef_))
sorted(zp, key = lambda x: x[1])
# Out:
# [('Condition2_PosN', -87689.59475564239),
#  ('Fireplaces_(2.25, 3.0]', -52719.605619528484),
#  ('PoolArea', -25285.47561196361),
#  ('KitchenQual_Fa', -19736.442041247996),
#  ('KitchenQual_TA', -18815.88350524706),
#  ('Neighborhood_Edwards', -15711.196493849318),
#  ('Utilities_NoSeWa', -15421.24931880795),
#  ('Condition1_RRAe', -15277.339070488351),
#  ('KitchenQual_Gd', -15183.339922340636),
#  ('LotFrontage', -13917.035841924877),
#  ('Heating_OthW', -13624.529652641782),
#  ('ExterCond_Gd', -13150.11064157153),
#  ('Neighborhood_Mitchel', -12801.807275246974),
#  ('BsmtQual_TA', -12711.20881985891),
#  ('Neighborhood_OldTown', -11902.353498749606),
#  ('GarageCond_Gd', -11729.741877975272),
#  ('BsmtQual_Gd', -11367.151373364106),
#  ('FireplaceQu_Fa', -11142.776193468695),
#  ('Functional_Maj2', -11069.083454428657),
#  ('LotConfig_FR3', -10925.432714902578),
#  ('Neighborhood_MeadowV', -10835.940895038495),
#  ('TotRmsAbvGrd_(11.0, 14.0]', -10332.311870663762),
# ...

# %%
ypred = model.predict(X_train)

# %%
r2_score(y_train, ypred)
# Out:
# 0.9371995981852719

# %%
# X_test[rem_col] = scaler.transform(X_test[rem_col])

# %%
# X_test = X_test[X_train.columns]

# %%
y_test_pred = model.predict(X_test)

# %%
r2_score(y_test, y_test_pred)
# Out:
# 0.8723474985589321

# %%
lasso = Lasso()

# %%
lasso.fit(X_train, y_train)
# Out:
# Lasso()

# %%
zp = list(zip(X_train.columns,lasso.coef_))
sorted(zp, key = lambda x: x[1])
# Out:
# [('Condition2_PosN', -290163.02556090185),
#  ('Fireplaces_(2.25, 3.0]', -273731.91205449676),
#  ('Utilities_NoSeWa', -33929.762665512404),
#  ('PoolArea', -26177.85708219805),
#  ('GarageQual_Po', -24494.40463460643),
#  ('KitchenQual_Fa', -23479.32586503378),
#  ('KitchenQual_TA', -21617.438947136525),
#  ('HouseStyle_2.5Fin', -21028.145575143782),
#  ('Foundation_Wood', -19696.94704843111),
#  ('KitchenQual_Gd', -18929.484279294444),
#  ('ExterCond_Gd', -17871.64020223368),
#  ('Neighborhood_Edwards', -17407.712625182943),
#  ('Condition1_RRAe', -16786.32092463807),
#  ('GarageCond_Gd', -15836.790076515717),
#  ('Heating_OthW', -15545.480243227386),
#  ('Neighborhood_Mitchel', -14911.182682373383),
#  ('Neighborhood_NAmes', -14361.937379453278),
#  ('ExterQual_TA', -14215.074772689311),
#  ('Functional_Maj2', -13923.56766247539),
#  ('Neighborhood_MeadowV', -13913.74101454267),
#  ('Neighborhood_OldTown', -13847.354395284972),
#  ('BedroomAbvGr_(4.0, 6.0]', -13821.495267552691),
# ...

# %%
yL_train_pred = lasso.predict(X_train)

# %%
r2_score(y_train, yL_train_pred)
# Out:
# 0.9463982683078451

# %%
yL_test_pred = lasso.predict(X_test)

# %%
r2_score(y_test, yL_test_pred)
# Out:
# 0.783527661662036

# %%
X_train.shape, y_train.shape , X_test.shape, y_test.shape
# Out:
# ((979, 280), (979,), (420, 280), (420,))

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression

# %%
degree = 2
poly = PolynomialFeatures(degree = degree, include_bias=False)

train,test = [],[]

C_values = [10, 1, 0.5, 0.1, 0.001]
#lamdba = [0.1, 1, 2, 10, 1000]

df = pd.DataFrame()
for c in C_values:
    ridgeclf = LogisticRegression(C=c) # By default using L2 Regularisation (Ridge)
    
    pipe = Pipeline([('polynomial_features',poly), ('logistic_regression',ridgeclf)])
    pipe.fit(X_train, y_train)

    y_train_pred = pipe.predict(X_train)
    train.append(r2_score(y_train, y_train_pred))
    
    y_test_pred = pipe.predict(X_test)
    test.append(r2_score(y_test, y_test_pred))
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-137-d45d049cb082> in <module>
#      12
#      13     pipe = Pipeline([('polynomial_features',poly), ('logistic_regression',ridgeclf)])
# ---> 14     pipe.fit(X_train, y_train)
#      15
#      16     y_train_pred = pipe.predict(X_train)
#
# c:\users\phani pranav\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\pipeline.py in fit(self, X, y, **fit_params)
#     333             if self._final_estimator != 'passthrough':
#     334                 fit_params_last_step = fit_params_steps[self.steps[-1][0]]
# --> 335                 self._final_estimator.fit(Xt, y, **fit_params_last_step)
#     336
#     337         return self
#
# c:\users\phani pranav\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\linear_model\_logistic.py in fit(self, X, y, sample_weight)
# ...

# %%
train,test

# %%
X_test
# Out:
#        LotArea  BsmtFinSF1  TotalBsmtSF  1stFlrSF  2ndFlrSF  GrLivArea  \
# 138  -0.012993    0.000021     0.000027 -0.076605  0.000257  -0.062870
# 212  -0.012993    0.000026     0.000024 -0.076609  0.000278  -0.062870
# 1187 -0.012993    0.000046     0.000044 -0.076573  0.000000  -0.062878
# 1006 -0.012993    0.000039     0.000044 -0.076571  0.000000  -0.062877
# 886  -0.012993    0.000017     0.000044 -0.076568  0.000000  -0.062875
# ...        ...         ...          ...       ...       ...        ...
# 1235 -0.012993    0.000000     0.000020 -0.076611  0.000270  -0.062872
# 780  -0.012993    0.000000     0.000033 -0.076592  0.000000  -0.062891
# 25   -0.012993    0.000000     0.000042 -0.076574  0.000000  -0.062879
# 420  -0.012993    0.000041     0.000036 -0.076587  0.000000  -0.062888
# 556  -0.012992    0.000028     0.000029 -0.076601  0.000000  -0.062897
#
#       GarageArea  PoolArea  Neighborhood_ClearCr  Condition2_PosN  \
# ...

# %%
X_train
# Out:
#        LotArea  BsmtFinSF1  TotalBsmtSF  1stFlrSF  2ndFlrSF  GrLivArea  \
# 162   0.094174    0.212792     0.252209  0.276962  0.000000   0.227393
# 743   0.100368    0.078668     0.085106  0.259293  0.000000   0.212886
# 1271  0.067554    0.000000     0.243699  0.265030  0.000000   0.217596
# 1110  0.057384    0.038802     0.126514  0.100734  0.486799   0.249435
# 344   0.009809    0.022856     0.087725  0.046352  0.316832   0.146571
# ...        ...         ...          ...       ...       ...        ...
# 846   0.068970    0.090893     0.121113  0.154199  0.422992   0.271477
# 55    0.076518    0.086818     0.233224  0.250344  0.000000   0.205539
# 367   0.067501    0.065734     0.179869  0.251721  0.000000   0.206669
# 82    0.076791    0.005847     0.255810  0.282010  0.000000   0.231537
# 836   0.058264    0.059887     0.255155  0.281092  0.000000   0.230784
#
#       GarageArea  PoolArea  Neighborhood_ClearCr  Condition2_PosN  \
# ...
